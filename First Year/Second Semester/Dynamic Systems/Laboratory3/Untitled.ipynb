# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + 4 * y
deq2 = diff(y, t) == x + y
syst = [deq1, deq2]
C1, C2 = var('C1, C2')
sol = desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == 2 * x - y
deq2 = diff(y, t) == x + 2 * y
syst = [deq1, deq2]
C1, C2 = var('C1, C2')
sol = desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == (C1*cos(t) - C2*sin(t))*e^(2*t),
#  y(t) == (C2*cos(t) + C1*sin(t))*e^(2*t)]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x, t) == x - y + z
deq2 = diff(y, t) == x + y - z
deq3 = diff(z, t) == -y + 2 * z
syst = [deq1, deq2, deq3]
C1, C2, C3 = var('C1, C2, C3')
sol = desolve_system(syst, [x, y, z], [0, C1, C2, C3])
show(sol)
# Out:
# [x(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t,
#  y(t) == C1*t*e^t - C3*t*e^t + C2*e^t,
#  z(t) == C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == 5 * x + 3 * y + 1
deq2 = diff(y, t) == -6 * x - 4 * y + e^(-t)
syst = [deq1, deq2]
C1, C2 = var('C1, C2')
sol = desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == 1/3*(6*C1 + 3*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(6*C1 + 3*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + 3 * y + cos(t)
deq2 = diff(y, t) == x - y + 2 * t
syst = [deq1, deq2]
C1, C2 = var('C1, C2')
sol = desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(10*C1 - 30*C2 - 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x, t) == x - 2 * y - 2 * z + e^(-t)
deq2 = diff(y, t) == -2 * x + y + 2 * z
deq3 = diff(z, t) == 2 * x - y - 3 * z + e^(-t)
syst = [deq1, deq2, deq3]
C1, C2, C3 = var('C1, C2, C3')
sol = desolve_system(syst, [x, y, z], [0, C1, C2, C3])
show(sol)
# Out:
# [x(t) == 1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) - C2*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t),
#  y(t) == -1/3*sqrt(3)*(2*C1 - C2 - 2*C3)*sinh(sqrt(3)*t) + C2*cosh(sqrt(3)*t),
#  z(t) == sqrt(3)*(C1 - C3)*sinh(sqrt(3)*t) - (C1 + C2 - C3)*cosh(sqrt(3)*t) + (C1 + C2)*e^(-t) + t*e^(-t)]

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + 4 * y 
deq2 = diff(y, t) == x + y
syst = [deq1, deq2]
sol = desolve_system(syst, [x, y], [0, 1, 2])
show(sol)
# Out:
# [x(t) == 5/2*e^(3*t) - 3/2*e^(-t), y(t) == 5/4*e^(3*t) + 3/4*e^(-t)]

# %%
sol_g(t) = sol[0].rhs()
g1 = plot(sol_g(t), t, -1, 1)
sol_g(t) = sol[1].rhs()
g2 = plot(sol_g(t), t, -1, 1, color = 'red')
show(g1 + g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x - y + t - 1 
deq2 = diff(y, t) == -2 * x + 4 * y + cos(t)
syst = [deq1, deq2]
sol = desolve_system(syst, [x, y], [0, 0, 1])
show(sol)
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]

# %%
sol_g(t) = sol[0].rhs()
g1 = plot(sol_g(t), t, -0.5, 1, ymin = -10, ymax = 10)
sol_g(t) = sol[1].rhs()
g2 = plot(sol_g(t), t, -0.5, 1, ymin = -10, ymax = 10, color = 'red')
show(g1 + g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + 2 * y + e^(-t) 
deq2 = diff(y, t) == -2 * x + y + 1
syst = [deq1, deq2]
sol = desolve_system(syst, [x, y], [0, 0, 1])
show(sol)
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]

# %%
sol_g(t) = sol[0].rhs()
g1 = plot(sol_g(t), t, -1, 5, ymin = -50)
sol_g(t) = sol[1].rhs()
g2 = plot(sol_g(t), t, -1, 5, color = 'red')
show(g1 + g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
z = function('z')(t)
deq1 = diff(x, t) == -x + 3 * y + 3 * z + 27 * t^2 
deq2 = diff(y, t) == 2 * x - 2 * y - 5 * z + 3 * t
deq3 = diff(z, t) == -2 * x + 3 * y + 6 * z + 3
syst = [deq1, deq2, deq3]
sol = desolve_system(syst, [x, y, z], [0, 50, -30, 26])
show(sol)
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]

# %%
sol_g(t) = sol[0].rhs()
g1 = plot(sol_g(t), t, -5, 20)
sol_g(t) = sol[1].rhs()
g2 = plot(sol_g(t), t, -5, 15, color = 'red')
sol_g(t) = sol[2].rhs()
g3 = plot(sol_g(t), t, -5, 15, color = 'green')
show(g1 + g2 + g3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == x + y
deq2 = diff(y, t) == -2 * x + 4 * y
syst = [deq1, deq2]
sol = desolve_system(syst, [x, y], [0, 3, 0])
show(sol)
# Out:
# [x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t)]

# %%
limit(sol[0], t = infinity)
# Out:
# limit(x(t), t, +Infinity) == -Infinity

# %%
limit(sol[1], t = infinity)
# Out:
# limit(y(t), t, +Infinity) == -Infinity

# %%
sol1 = desolve_system(syst, [x, y], [0, 0, 3])
show(sol1)
# Out:
# [x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t)]

# %%
limit(sol1[0], t = infinity)
# Out:
# limit(x(t), t, +Infinity) == +Infinity

# %%
limit(sol1[1], t = infinity)
# Out:
# limit(y(t), t, +Infinity) == +Infinity

# %%
sol2 = desolve_system(syst, [x, y], [0, -3, 0])
show(sol2)
# Out:
# [x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t)]

# %%
limit(sol2[0], t = infinity)
# Out:
# limit(x(t), t, +Infinity) == +Infinity

# %%
limit(sol2[1], t = infinity)
# Out:
# limit(y(t), t, +Infinity) == +Infinity

# %%
sol3 = desolve_system(syst, [x, y], [0, 0, -3])
show(sol3)
# Out:
# [x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t)]

# %%
limit(sol3[0], t = infinity)
# Out:
# limit(x(t), t, +Infinity) == -Infinity

# %%
limit(sol3[1], t = infinity)
# Out:
# limit(y(t), t, +Infinity) == -Infinity

# %%
f1(u, v) = u + v
f2(u, v) = -2 * u + 4 * v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g1 = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

sol_x(t) = sol[0].rhs()
sol_y(t) = sol[1].rhs()
sol1_x(t) = sol1[0].rhs()
sol1_y(t) = sol1[1].rhs()
sol2_x(t) = sol2[0].rhs()
sol2_y(t) = sol2[1].rhs()
sol3_x(t) = sol3[0].rhs()
sol3_y(t) = sol3[1].rhs()

g2 = parametric_plot((sol_x(t), sol_y(t)), (t, -1, 1), color = 'blue')
g3 = parametric_plot((sol1_x(t), sol1_y(t)), (t, -1, 1), color = 'blue')
g4 = parametric_plot((sol2_x(t), sol2_y(t)), (t, -1, 1), color = 'blue')
g5 = parametric_plot((sol3_x(t), sol3_y(t)), (t, -1, 1), color = 'blue')

g = g1 + g2 + g3 + g4 + g5

show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 5 graphics primitives

# %%
t = var('t')
x = function('x')(t)
y = function('y')(t)
deq1 = diff(x, t) == y
deq2 = diff(y, t) == -x - 2 * y
syst = [deq1, deq2]
C1, C2 = var('C1, C2')
sol = desolve_system(syst, [x, y], [0, C1, C2])
show(sol)
# Out:
# [x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t),
#  y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)]

# %%
limit(sol[0], t = infinity)
# Out:
# limit(x(t), t, +Infinity) == 0

# %%
limit(sol[1], t = infinity)
# Out:
# limit(y(t), t, +Infinity) == 0

# %%
f1(u, v) = v
f2(u, v) = -u - 2 * v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g1 = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

show(g1, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = 2 * u + v
f2(u, v) = u + 2 * v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)
show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = -u - v
f2(u, v) = u - v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = v
f2(u, v) = -u
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = -2 * u
f2(u, v) = -4 * u - 2 * v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = u - 4 * v
f2(u, v) = 5 * u - 3 * v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(u, v) = 3 * u - v
f2(u, v) = v
n = sqrt(f1(u, v)^2 + f2(u, v)^2)
g = plot_vector_field([f1(u, v) / n, f2(u, v) / n], [u, -10, 10], [v, -10, 10], aspect_ratio = 1)

show(g, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive
